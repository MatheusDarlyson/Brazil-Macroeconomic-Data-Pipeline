# %% [markdown]
# Consumo de API do IBGE
#
# Retorno esperado : Dados sobre PIB (BRA)

# %%
import pandas as pd  #possibilita manipulação e análise de dados
import requests  #possibilita integração com serviços web, solicitações HTTP consumir dados de APIs

# %%
url = "https://servicodados.ibge.gov.br/api/v3/agregados/5938/periodos/2002|2003|2004|2005|2006|2007|2008|2009|2010|2011|2012|2013|2014|2015|2016|2017|2018|2019|2020|2021/variaveis/37?localidades=N1[all]"

# %%
# Realizar a requisição
response = requests.get(url)

# Verificar se a requisição foi bem-sucedida
if response.status_code == 200:
    # Converter os dados para JSON
    data = response.json()

# %%
# Extração e exibição dos valores de interesse
try:
        resultados = data[0]["resultados"][0]["series"]  # Navega até os dados
        for serie in resultados:
            localidade = serie["localidade"]["nome"]  # Nome da localidade
            print(f"Localidade: {localidade}")
            
            for periodo, valor in serie["serie"].items():  # Itera sobre os períodos e valores
                print(f"Período: {periodo}, Valor do PIB: {valor}")
except KeyError as e:
        print(f"Erro ao processar os dados: {e}")
# Out:
# Localidade: Brasil
# Período: 2002, Valor do PIB: 1488787276
# Período: 2003, Valor do PIB: 1717950386
# Período: 2004, Valor do PIB: 1957751224
# Período: 2005, Valor do PIB: 2170584503
# Período: 2006, Valor do PIB: 2409449916
# Período: 2007, Valor do PIB: 2720262951
# Período: 2008, Valor do PIB: 3109803097
# Período: 2009, Valor do PIB: 3333039339
# Período: 2010, Valor do PIB: 3885847000
# Período: 2011, Valor do PIB: 4376382000
# Período: 2012, Valor do PIB: 4814760000
# Período: 2013, Valor do PIB: 5331618957
# Período: 2014, Valor do PIB: 5778952780
# Período: 2015, Valor do PIB: 5995787000
# Período: 2016, Valor do PIB: 6269328000
# Período: 2017, Valor do PIB: 6585479000
# Período: 2018, Valor do PIB: 7004141000
# Período: 2019, Valor do PIB: 7389131000
# Período: 2020, Valor do PIB: 7609597000
# Período: 2021, Valor do PIB: 9012142000
