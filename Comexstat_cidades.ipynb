# %% [markdown]
# Consumo de API Comexstat
#
# Retorno esperado :
#
# * Dados de Importação e Exportação desde 2020, por estados.
# * Dados de Importação e Exportação desde 2020, por cidades.

# %%
import pandas as pd
import requests  
import json  
import urllib3

# %% [markdown]
# Dados por Cidade

# %%
# Desabilitar a verificação de certificado SSL
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

url = "https://api-comexstat.mdic.gov.br/cities"

headers = {
    "Content-Type": "application/json"
}

filtros = {
    "flow": "export",
    "monthDetail": True,
    "period": {"from": "2020-01", "to": "2024-12"},
    "filters": [ { "filter": "country", "values": [ 105] }],
    "details": [ "city"],
    "metrics": ["metricFOB", "metricKG"]
}

# Fazendo a requisição POST com verify=False
response = requests.post(url, json=filtros, headers=headers, verify=False)

# %%
# Checando se a requisição foi bem-sucedida
if response.status_code == 200:
    dados = response.json()  # Converte a resposta em JSON
    print(dados)
else:
    print("Erro:", response.status_code, response.text)
# Out:
# {'data': {'list': [{'noMunMinsgUf': 'Guarulhos - SP', 'year': '2024', 'monthNumber': '09', 'metricFOB': '103086688', 'metricKG': '111856076'}, {'noMunMinsgUf': 'Guarulhos - SP', 'year': '2024', 'monthNumber': '05', 'metricFOB': '97379792', 'metricKG': '98362487'}, {'noMunMinsgUf': 'Guarulhos - SP', 'year': '2024', 'monthNumber': '08', 'metricFOB': '56663536', 'metricKG': '59765065'}, {'noMunMinsgUf': 'Guarulhos - SP', 'year': '2024', 'monthNumber': '10', 'metricFOB': '26749219', 'metricKG': '32293979'}, {'noMunMinsgUf': 'Guarulhos - SP', 'year': '2024', 'monthNumber': '01', 'metricFOB': '18946758', 'metricKG': '17198150'}, {'noMunMinsgUf': 'Guarulhos - SP', 'year': '2024', 'monthNumber': '03', 'metricFOB': '17949888', 'metricKG': '17387959'}, {'noMunMinsgUf': 'Guarulhos - SP', 'year': '2024', 'monthNumber': '07', 'metricFOB': '17519024', 'metricKG': '20099229'}, {'noMunMinsgUf': 'Brasília - DF', 'year': '2024', 'monthNumber': '09', 'metricFOB': '9422785', 'metricKG': '8693724'}, {'noMunMinsgUf': 'Fortaleza - CE', 'year': '2024', 'monthNumber': '09', 'metricFOB': '7446345', 'metricKG': '7909361'}, {'noMunMinsgUf': 'Rio de Janeiro - RJ', 'year': '2024', 'monthNumber': '09', 'metricFOB': '5906315', 'metricKG': '5568177'}, {'noMunMinsgUf': 'Rio de Janeiro - RJ', 'year': '2024', 'monthNumber': '03', 'metricFOB': '5604552', 'metricKG': '5430592'}, {'noMunMinsgUf': 'Rio de Janeiro - RJ', 'year': '2024', 'monthNumber': '05', 'metricFOB': '4624344', 'metricKG': '4533615'}, {'noMunMinsgUf': 'Duque de Caxias - RJ', 'year': '2024', 'monthNumber': '10', 'metricFOB': '4015135', 'metricKG': '9840670'}, {'noMunMinsgUf': 'Campinas - SP', 'year': '2024', 'monthNumber': '08', 'metricFOB': '3594731', 'metricKG': '3878029'}, {'noMunMinsgUf': 'Brasília - DF', 'year': '2024', 'monthNumber': '08', 'metricFOB': '3550567', 'metricKG': '3520915'}, {'noMunMinsgUf': 'Campinas - SP', 'year': '2024', 'monthNumber': '03', 'metricFOB': '3524577', 'metricKG': '3617966'}, {'noMunMinsgUf': 'Rio de Janeiro - RJ', 'year': '2024', 'monthNumber': '10', 'metricFOB': '3463634', 'metricKG': '3321732'}, {'noMunMinsgUf': 'Campinas - SP', 'year': '2024', 'monthNumber': '09', 'metricFOB': '3164231', 'metricKG': '3256508'}, {'noMunMinsgUf': 'Campinas - SP', 'year': '2024', 'monthNumber': '05', 'metricFOB': '3096175', 'metricKG': '3035808'}, {'noMunMinsgUf': 'Rio de Janeiro - RJ', 'year': '2024', 'monthNumber': '08', 'metricFOB': '2975453', 'metricKG': '3101338'}, {'noMunMinsgUf': 'Brasília - DF', 'year': '2024', 'monthNumber': '10', 'metricFOB': '2540892', 'metricKG': '2218945'}, {'noMunMinsgUf': 'Rio de Janeiro - RJ', 'year': '2024', 'monthNumber': '07', 'metricFOB': '2496059', 'metricKG': '2646183'}, {'noMunMinsgUf': 'Duque de Caxias - RJ', 'year': '2024', 'monthNumber': '09', 'metricFOB': '2226561', 'metricKG': '7105264'}, {'noMunMinsgUf': 'Campinas - SP', 'year': '2024', 'monthNumber': '07', 'metricFOB': '2222041', 'metricKG': '2401764'}, {'noMunMinsgUf': 'Florianópolis - SC', 'year': '2024', 'monthNumber': '09', 'metricFOB': '2191371', 'metricKG': '2195388'}, {'noMunMinsgUf': 'Santos - SP', 'year': '2024', 'monthNumber': '01', 'metricFOB': '2134624', 'metricKG': '3549034'}, {'noMunMinsgUf': 'Santos - SP', 'year': '2024', 'monthNumber': '08', 'metricFOB': '2077126', 'metricKG': '3503294'}, {'noMunMinsgUf': 'Santos - SP', 'year': '2024', 'monthNumber': '06', 'metricFOB': '1932921', 'metricKG': '3246364'}, {'noMunMinsgUf': 'Campinas - SP', 'year': '2024', 'monthNumber': '10', 'metricFOB': '1684075', 'metricKG': '1892267'}, {'noMunMinsgUf': 'Lagoa Santa - MG', 'year': '2024', 'monthNumber': '08', 'metricFOB': '1607955', 'metricKG': '1690109'}, {'noMunMinsgUf': 'Santos - SP', 'year': '2024', 'monthNumber': '07', 'metricFOB': '1584233', 'metricKG': '2497768'}, {'noMunMinsgUf': 'Santos - SP', 'year': '2024', 'monthNumber': '04', 'metricFOB': '1544304', 'metricKG': '2349206'}, {'noMunMinsgUf': 'São José dos Pinhais - PR', 'year': '2024', 'monthNumber': '08', 'metricFOB': '1468 ...

# %%
# Extrair a lista de dados
data_list = dados['data']['list']

# Transformar em DataFrame
dados_pd = pd.DataFrame(data_list)

# Exibir o DataFrame
dados_pd.sample(20)
# Out:
#              noMunMinsgUf  year monthNumber metricFOB metricKG
# 35   Duque de Caxias - RJ  2024          07   1297385  4372464
# 205         Salvador - BA  2023          12    201495   169916
# 321     Porto Alegre - RS  2022          11    348239   252251
# 33            Santos - SP  2024          05   1437701  2248641
# 225        Fortaleza - CE  2023          03     89861    75941
# 86      Porto Alegre - RS  2024          01     81169    71157
# 211      Lagoa Santa - MG  2023          12    162514   141574
# 144          Vitória - ES  2024          07      3428      373
# 358        Paranaguá - PR  2021          11      7811     8919
# 51            Manaus - AM  2024          08    681632   644702
# 186        Fortaleza - CE  2023          12    632364   537358
# 222        Rio Largo - AL  2023          12    101003    86766
# 362           Santos - SP  2021          06      1845        1
# 251        Fortaleza - CE  2023          05     21868    14479
# 140    Florianópolis - SC  2024          02      3719     2623
# 357           Maceió - AL  2021          08      8195     3721
# 73            Manaus - AM  2024          07    224948   204875
# 242      Lagoa Santa - MG  2023          10     39879    32186
# 277           Maceió - AL  2023          03      7619     2323
# 10    Rio de Janeiro - RJ  2024          03   5604552  5430592

# %%
dados_pd.shape
# Out:
# (389, 5)

# %%
dados_pd["noMunMinsgUf"].value_counts()
# Out:
# noMunMinsgUf
# Rio de Janeiro - RJ             28
# Santos - SP                     28
# Guarulhos - SP                  26
# Manaus - AM                     25
# Porto Alegre - RS               23
# São José dos Pinhais - PR       21
# Florianópolis - SC              21
# Campinas - SP                   20
# Brasília - DF                   19
# Belém - PA                      18
# Lagoa Santa - MG                17
# Foz do Iguaçu - PR              16
# Duque de Caxias - RJ            16
# Recife - PE                     16
# Fortaleza - CE                  13
# São Gonçalo do Amarante - RN    10
# Boa Vista - RR                  10
# Maceió - AL                      9
# Salvador - BA                    9
# Paranaguá - PR                   7
# Vitória - ES                     6
# Macaé - RJ                       5
# Rio Grande - RS                  5
# Rio Largo - AL                   5
# Campo Grande - MS                3
# São Francisco do Conde - BA      2
# Araucária - PR                   1
# Sumaré - SP                      1
# Vila Velha - ES                  1
# São Luís - MA                    1
# Porto Seguro - BA                1
# Macapá - AP                      1
# São Sebastião - SP               1
# Franca - SP                      1
# Raposa - MA                      1
# Queimados - RJ                   1
# São José dos Campos - SP         1
# Name: count, dtype: int64
