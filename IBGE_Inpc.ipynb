# %% [markdown]
# Consumo de API do IBGE
#
# Retorno esperado : Dados sobre INPC

# %%
import pandas as pd  #possibilita manipulação e análise de dados
import requests  #possibilita integração com serviços web, solicitações HTTP consumir dados de APIs

# %%
# Endpoint da API para consulta do INPC entre 10/2006 e 10/2007 
url = "https://servicodados.ibge.gov.br/api/v3/agregados/2951/periodos/200610|200710/variaveis/44?localidades=N1[all]&classificacao=315[all]"

# %%
# Realizar a requisição
response = requests.get(url)

# Verificar se a requisição foi bem-sucedida
if response.status_code == 200:
    # Converter os dados para JSON
    data = response.json()

# %%
# Exibir os dados formatados (opcional, para depuração)
print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "id": "44",
#         "variavel": "INPC - Variação mensal",
#         "unidade": "%",
#         "resultados": [
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7169": "Índice geral"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.43",
#                             "200710": "0.30"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7170": "1.Alimentação e bebidas"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "1.10",
#                             "200710": "0.55"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7171": "11.Alimentação no domicílio"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "1.26",
#                             "200710": "0.51"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7172": "1101.Cereais, leguminosas e oleaginosas"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "1.24",
#                             "200710": "6.91"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7173": "1101002.Arroz"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.44",
#                             "200710": "2.08"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7795": "1101049.Feijão - manteiga"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-2.44",
#                             "200710": "0.04"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7175": "1101051.Feijão - mulatinho"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "1.47",
#                             "200710": "14.19"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7176": "1101052.Feijão - preto"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-1.62",
#                             "200710": "10.01"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7177": "1101053.Feijão - macassar (fradinho)"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "4.05",
#                             "200710": "7.26"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7180": "1101073.Feijão - carioca (rajado))"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "4.62",
#                             "200710": "17.55"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7181": "1101079.Milho em grão"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-0.28",
#                             "200710": "0.77"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7184": "1102.Farinhas, féculas e massas"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.44",
#                             "200710": "1.23"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7185": "1102001.Farinha de arroz"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "1.82",
#                             "200710": "-0.74"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7187": "1102006.Macarrão"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-0.92",
#                             "200710": "1.86"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7188": "1102008.Fubá de milho"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-0.25",
#                             "200710": "0.88"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7189": "1102009.Amido de milho"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-0.22",
#                             "200710": "1.75"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7190": "1102010.Flocos de milho"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-0.53",
#                             "200710": "-0.99"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7191": "1102012.Farinha de trigo"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "1.23",
#                             "200710": "2.35"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7192": "1102013.Farinha vitaminada"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.42",
#                             "200710": "0.19"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7193": "1102016.Flocos de cereais"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "1.54",
#                             "200710": "-0.49"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7195": "1102023.Farinha de mandioca"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "3.09",
#                             "200710": "0.50"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "107608": "1102029.Massa semipreparada"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-1.86",
#                             "200710": "0.68"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7200": "1103.Tubérculos, raízes e legumes"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "5.39",
#                             "200710": "7.93"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7202": "1103003.Batata-inglesa"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "12.21",
#                             "200710": "14.69"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7203": "1103004.Inhame"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "10.10",
#                             "200710": "11.06"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7204": "1103005.Mandioca (aipim)"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-4.18",
#                             "200710": "16.22"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7205": "1103017.Abóbora"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-3.79",
#                             "200710": "13.76"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7207": "1103021.Chuchu"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-20.49",
#                             "200710": "-11.91"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7210": "1103026.Pimentão"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "1.50",
#                             "200710": "9.76"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7211": "1103027.Quiabo"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-3.25",
#                             "200710": "28.06"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7212": "1103028.Tomate"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "17.41",
#                             "200710": "1.68"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7215": "1103043.Cebola"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-6.59",
#                             "200710": "7.12"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7216": "1103044.Cenoura"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-7.85",
#                             "200710": "5.01"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7219": "1104.Açúcares e derivados"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-3.31",
#                             "200710": "-2.76"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7220": "1104003.Açúcar refinado"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-3.67",
#                             "200710": "-3.73"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7221": "1104004.Açúcar cristal"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-5.88",
#                             "200710": "-5.09"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "107609": "1104023.Chocolate em barra e bombom"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.37",
#                             "200710": "-2.45"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "107610": "1104028.Gelatina"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-1.18",
#                             "200710": "-1.00"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7230": "1104032.Sorvete"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.16",
#                             "200710": "2.23"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "107611": "1104052.Chocolate e achocolatado em pó"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.06",
#                             "200710": "-0.41"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7233": "1104060.Doce de frutas em pasta"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-0.25",
#                             "200710": "-1.72"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7235": "1104066.Doce de leite"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "1.07",
#                             "200710": "3.46"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7241": "1105.Hortaliças e verduras"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-0.02",
#                             "200710": "-1.16"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7242": "1105001.Alface"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-0.32",
#                             "200710": "1.27"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7244": "1105004.Coentro"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-1.76",
#                             "200710": "-5.07"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7245": "1105005.Couve"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-0.31",
#                             "200710": "-0.75"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7246": "1105006.Couve-flor"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-2.25",
#                             "200710": "-1.76"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7248": "1105010.Repolho"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "1.95",
#                             "200710": "-9.76"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7249": "1105012.Cheiro-verde"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "1.78",
#                             "200710": "-1.52"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7250": "1105013.Agrião"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "5.33",
#                             "200710": "10.83"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7253": "1105019.Brócolis"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-6.09",
#                             "200710": "14.15"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7254": "1106.Frutas"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "1.34",
#                             "200710": "5.34"
# ...
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "2.27",
#                             "200710": "-0.91"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "107678": "8104.Cursos diversos"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.42",
#                             "200710": "0.02"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "107679": "8104001.Curso preparatório"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.51",
#                             "200710": "0.00"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "107680": "8104002.Curso técnico"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "1.60",
#                             "200710": "0.00"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "107681": "8104003.Curso de idioma"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.03",
#                             "200710": "0.00"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "107682": "8104004.Curso de informática"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-0.04",
#                             "200710": "0.00"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "107683": "8104005.Autoescola"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.26",
#                             "200710": "1.46"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "107684": "8104006.Ginástica"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.23",
#                             "200710": "0.00"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "107687": "8104009.Escolinha de esporte"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.00",
#                             "200710": "0.00"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7786": "9.Comunicação"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-0.10",
#                             "200710": "-0.01"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7787": "91.Comunicação"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-0.10",
#                             "200710": "-0.01"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7788": "9101.Comunicação"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-0.10",
#                             "200710": "-0.01"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7789": "9101001.Correio"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.00",
#                             "200710": "0.00"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7790": "9101002.Telefone fixo"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.00",
#                             "200710": "0.03"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7791": "9101003.Telefone público"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.06",
#                             "200710": "0.43"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7792": "9101008.Telefone celular"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.44",
#                             "200710": "0.00"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7793": "9101010.TV a cabo"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "0.01",
#                             "200710": "0.02"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "classificacoes": [
#                     {
#                         "id": "315",
#                         "nome": "Geral, grupo, subgrupo, item e subitem",
#                         "categoria": {
#                             "7794": "9101019.Aparelho telefônico"
#                         }
#                     }
#                 ],
#                 "series": [
#                     {
#                         "localidade": {
#                             "id": "1",
#                             "nivel": {
#                                 "id": "N1",
#                                 "nome": "Brasil"
#                             },
#                             "nome": "Brasil"
#                         },
#                         "serie": {
#                             "200610": "-2.19",
#                             "200710": "-0.90"
#                         }
#                     }
#                 ]
#             }
#         ]
#     }
# ]

# %%
# Extração e exibição dos valores de interesse
try:
        resultados = data[0]["resultados"][0]["series"]  # Navega até os dados
        for serie in resultados:
            localidade = serie["localidade"]["nome"]  # Nome da localidade
            print(f"Localidade: {localidade}")
            
            for periodo, valor in serie["serie"].items():  # Itera sobre os períodos e valores
                print(f"Período: {periodo}, Valor do INPC: {valor}")
except KeyError as e:
        print(f"Erro ao processar os dados: {e}")
# Out:
# Localidade: Brasil
# Período: 200610, Valor do INPC: 0.43
# Período: 200710, Valor do INPC: 0.30
